# %%
import os

value = os.getenv("FAVORITE_COLOR")
print("Your favorite color is:", value)
# Out:
# Your favorite color is: None

# %%
from dotenv import load_dotenv
load_dotenv(override=True)
# Out:
# False
